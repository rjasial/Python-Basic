# %% [markdown]
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program.
#
# In Python, variables are created when you assign a value to them. Python does not require explicit variable declarations or manual memory allocation. The interpreter automatically determines the data type and allocates memory when the assignment happens.
#
# Introduction to Variables
#
# Declaring and Assigning Variables
#
# Naming Conventions
#
# Variable Types
#
# Dynamic Typing (IMPORTANT in Python)
#
# Type Checking (type())
#
# Type Conversion (int(), str(), float())

# %%
## Dynamic Typing
## Python allows the type of a variable to change as the program executes

var = 10   # int
print(var, type(var))

var = "Hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
### Simple calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 4.0
# Difference: 0.0
# Product: 4.0
# Quotient: 1.0
